# %%
import optuna
import pandas as pd

study = pd.read_csv ("data/weighted_loss_optuna_results.csv")



print(study.head())
# Out:
#    number     value              datetime_start           datetime_complete  \
# 0       0  1.369621  2026-08-31 14:32:51.227438  2026-08-31 14:47:47.960986
# 1       1  1.524522  2026-08-31 14:47:47.961573  2026-08-31 15:02:39.455126
# 2       2  1.369749  2026-08-31 15:02:39.455411  2026-08-31 15:17:31.075352
# 3       3  1.430132  2026-08-31 15:17:31.075645  2026-08-31 15:32:23.823818
# 4       4  1.515304  2026-08-31 15:32:23.824162  2026-08-31 15:47:16.988235
#
#                  duration  params_beta  params_threshold  \
# 0  0 days 00:14:56.733548            5          3.640191
# 1  0 days 00:14:51.493553            3          3.665018
# 2  0 days 00:14:51.619941            5          3.737206
# 3  0 days 00:14:52.748173            4          3.961103
# 4  0 days 00:14:53.164073            2          3.757800
#
#    user_attrs_best_epoch                         user_attrs_checkpoint_path  \
# 0                     39  /home/ec2-user/Earthquake/weightedtraining/dat...
# ...

# %%
study.sort_values("value")

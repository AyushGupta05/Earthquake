# %%
import optuna
import pandas as pd

study = optuna.load_study(
    study_name="earthquake_architecture_search",
    storage="sqlite:///../architechturesearch/data/architecture_search.db"
)

df = study.trials_dataframe()

print(df.head())
# Out:
#    number  value             datetime_start          datetime_complete  \
# 0       0    NaN 2026-08-23 17:39:43.836771 2026-08-23 17:39:44.043443
# 1       1    NaN 2026-08-23 17:55:38.481763 2026-08-23 17:55:38.896239
# 2       2    NaN 2026-08-23 17:56:47.681707 2026-08-23 17:57:54.087425
# 3       3    NaN 2026-08-23 18:00:42.122401 2026-08-23 18:10:24.909726
# 4       4    NaN 2026-08-23 18:12:34.467122 2026-08-23 18:37:09.454811
#
#                 duration  params_fc_size  params_initial_filters  \
# 0 0 days 00:00:00.206672             128                      32
# 1 0 days 00:00:00.414476             128                      16
# 2 0 days 00:01:06.405718             256                      16
# 3 0 days 00:09:42.787325             128                      64
# 4 0 days 00:24:34.987689             256                      32
#
#    params_kernel_size  params_n_layers  params_use_batchnorm  \
# 0                   5                2                  True
# 1                   5                4                  True
# 2                   7                5                  True
# 3                   7                3                 False
# 4                   5                3                 False
#
#    user_attrs_best_epoch  user_attrs_best_val_accuracy_0.2  \
# 0                    NaN                               NaN
# 1                    NaN                               NaN
# 2                    NaN                               NaN
# 3                    NaN                               NaN
# 4                    NaN                               NaN
#
#    user_attrs_best_val_mae  user_attrs_best_val_mse  user_attrs_best_val_rmse  \
# 0                      NaN                      NaN                       NaN
# 1                      NaN                      NaN                       NaN
# 2                      NaN                      NaN                       NaN
# 3                      NaN                      NaN                       NaN
# 4                      NaN                      NaN                       NaN
#
#    user_attrs_trainable_params state
# 0                        19457  FAIL
# 1                        71361  FAIL
# 2                       372513  FAIL
# 3                       321537  FAIL
# 4                        85185  FAIL

# %%
complete_df = df[df["state"] == "COMPLETE"]

# %%
complete_df
# Out:
#     number     value             datetime_start          datetime_complete  \
# 10      10  0.701219 2026-08-24 15:24:24.063411 2026-08-24 15:25:56.267402
# 11      11  0.654623 2026-08-24 15:25:56.285372 2026-08-24 15:27:23.312668
# 12      12  0.605119 2026-08-24 15:27:23.326857 2026-08-24 15:29:05.179060
# 13      13  0.675934 2026-08-24 15:29:05.193291 2026-08-24 15:31:16.983306
# 14      14  0.654174 2026-08-24 15:31:16.995080 2026-08-24 15:32:43.642283
#
#                  duration  params_fc_size  params_initial_filters  \
# 10 0 days 00:01:32.203991             128                      32
# 11 0 days 00:01:27.027296              32                      16
# 12 0 days 00:01:41.852203             256                      32
# 13 0 days 00:02:11.790015             256                      64
# 14 0 days 00:01:26.647203              64                      16
#
#     params_kernel_size  params_n_layers  params_use_batchnorm  \
# 10                   7                2                  True
# 11                   7                2                 False
# 12                   3                5                 False
# 13                   7                5                  True
# 14                   3                2                 False
#
#     user_attrs_best_epoch  user_attrs_best_val_accuracy_0.2  \
# 10                    5.0                         38.062541
# 11                   10.0                         34.734465
# 12                   10.0                         34.434444
# 13                    5.0                         34.018950
# 14                   10.0                         34.806636
#
#     user_attrs_best_val_mae  user_attrs_best_val_mse  \
# 10                 0.513830                 0.491708
# 11                 0.492509                 0.428532
# 12                 0.455013                 0.366170
# 13                 0.496432                 0.456887
# 14                 0.492536                 0.427943
#
#     user_attrs_best_val_rmse  user_attrs_trainable_params     state
# 10                  0.701219                        23745  COMPLETE
# 11                  0.654623                         5057  COMPLETE
# 12                  0.605119                       392705  COMPLETE
# 13                  0.675934                      1274497  COMPLETE
# 14                  0.654174                         3905  COMPLETE
